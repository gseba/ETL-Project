# %%
import hawk_transform as ht
import pymongo
import pprint
import re
import time as t
# Out:
# ...starting EXTRACT of Seba Tables.
#
# ----------------------------------
# Seba Tables Extracted!
# ----------------------------------
# Return: 5 Dataframes
# ----------------------------------
#
#
# Seba Tables Received.
# ----------------------------------
# ...beginning Hawk TRANSFORM
#
#
# ----------------------------------
# Hawk List Transformed!
# ----------------------------------
# Return: Master List of Dictionaries

# %%
print(f"""
Master List Received.
----------------------------------
...beginning Wood LOAD
""")
# Out:
# Master List Received.
# ----------------------------------
# ...beginning Wood LOAD

# %%
#-----/ CONNECT TO MONGO /---------------------
#----------------------------------------------

def connect_mongo():
    conn = "mongodb://localhost:27017"
    client = pymongo.MongoClient(conn)
    print(f"You're connected! Passing back the client.")
    return client

#-----/ CREATE COLLECTION /---------------------

def mongo_me(db,col):
    client = connect_mongo()
    collection = client[db][col]
    print(f"You're connected to DB:{db} | Collection:{col}")
    return collection

#-----/ INITIALIZE COLLECTION TO MONGO /---------------------

def init_mongo(db,col):
    collection = mongo_me(db,col)
    post_this = {
    'date':t.strftime('%Y-%m-%d'),
    'timestamp':t.strftime('%y%m%d%H%M%s'),
    'post':'Posted!'
    }
    collection.insert_one(post_this)
    return collection.find_one(sort=[('timestamp', pymongo.DESCENDING)])

#-----/ LOAD DICTIONARY /---------------------

def load_it(dict,db,col):
    collection = mongo_me(db,col)
    collection.insert_many(dict)
    count = collection.estimated_document_count()
    print('Loaded!')
    print(f"You inserted {count} documents into the {col} collection of the {db} Database.")
    return collection


#-----/ GET LAST ITEM /---------------------

def last_doc(collection):
    last = collection.estimated_document_count()-1
    return collection.find()[last]


#-----/ GET ENTIRE COLLECTION AS LIST OF DICTIONARIES /---------------------
def collection_list(collection):
    my_list = []
    for d in collection.find():
        my_list.append(d)
    return my_list

#-----/ DROP MongoDB /---------------------
def drop(db_name):
    client = connect_mongo()
    client.drop_database(db_name)
    return client.list_database_names()

# %%
#-------/ List Received /------------
cal_cities = ht.master_list

#-------/ Define DB & Collection Name /------------
my_db = 'sebahawkwood_db'
my_col = 'cal_cities'

#-------/ Load List, Get Collection  /------------
drop(my_db)
cal_collection = load_it(cal_cities,my_db,my_col)
# Out:
# You're connected! Passing back the client.
# You're connected! Passing back the client.
# You're connected to DB:sebahawkwood_db | Collection:cal_cities
# Loaded!
# You inserted 391 documents into the cal_cities collection of the sebahawkwood_db Database.

# %%
last_doc(cal_collection)
# Out:
# {'_id': ObjectId('5da655ec57b4a93712a1f01e'),
#  'City': 'Yucaipa',
#  'County': 'San Bernardino',
#  'Population': '51367',
#  'Violent crimes': 71,
#  'Property Crimes': 978,
#  'Median Age': '37.80',
#  'Median Home Price': ' 220,000 ',
#  'Labor Force': '25,300',
#  'Employment': '24,400',
#  'Unemployment Number': '800',
#  'Unemployment Rate': '3.4%'}

# %%
collection_list(cal_collection)
# Out:
# [{'_id': ObjectId('5da655ec57b4a93712a1ee98'),
#   'City': 'Adelanto',
#   'County': 'San Bernardino',
#   'Population': '31765',
#   'Violent crimes': 189,
#   'Property Crimes': 790,
#   'Median Age': '25.30',
#   'Median Home Price': ' 143,000 ',
#   'Labor Force': '9,700',
#   'Employment': '8,900',
#   'Unemployment Number': '800',
#   'Unemployment Rate': '8.1%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1ee99'),
#   'City': 'Agoura Hills',
#   'County': 'Los Angeles',
#   'Population': '20330',
#   'Violent crimes': 17,
#   'Property Crimes': 234,
#   'Median Age': '42.40',
#   'Median Home Price': ' 405,000 ',
#   'Labor Force': '11,600',
#   'Employment': '11,100',
#   'Unemployment Number': '500',
#   'Unemployment Rate': '4.2%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1ee9a'),
#   'City': 'Alameda',
#   'County': 'Alameda',
#   'Population': '73812',
#   'Violent crimes': 145,
#   'Property Crimes': 1723,
#   'Median Age': '40.70',
#   'Median Home Price': ' 617,000 ',
#   'Labor Force': '42,300',
#   'Employment': '41,100',
#   'Unemployment Number': '1,200',
#   'Unemployment Rate': '2.8%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1ee9b'),
#   'City': 'Albany',
#   'County': 'Alameda',
#   'Population': '18539',
#   'Violent crimes': 31,
#   'Property Crimes': 478,
#   'Median Age': '37.00',
#   'Median Home Price': ' 804,000 ',
#   'Labor Force': '10,000',
#   'Employment': '9,700',
#   'Unemployment Number': '200',
#   'Unemployment Rate': '2.4%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1ee9c'),
#   'City': 'Alhambra',
#   'County': 'Los Angeles',
#   'Population': '83089',
#   'Violent crimes': 168,
#   'Property Crimes': 1743,
#   'Median Age': '39.30',
#   'Median Home Price': ' 477,000 ',
#   'Labor Force': '46,500',
#   'Employment': '44,700',
#   'Unemployment Number': '1,800',
#   'Unemployment Rate': '3.9%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1ee9d'),
#   'City': 'Aliso Viejo',
#   'County': 'Orange',
#   'Population': '47823',
#   'Violent crimes': 35,
#   'Property Crimes': 273,
#   'Median Age': '35.10',
#   'Median Home Price': ' 417,000 ',
#   'Labor Force': '30,200',
#   'Employment': '29,400',
#   'Unemployment Number': '800',
#   'Unemployment Rate': '2.8%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1ee9e'),
#   'City': 'American Canyon',
#   'County': 'Napa',
#   'Population': '19454',
#   'Violent crimes': 55,
#   'Property Crimes': 568,
#   'Median Age': '35.50',
#   'Median Home Price': ' 269,000 ',
#   'Labor Force': '10,600',
#   'Employment': '10,200',
#   'Unemployment Number': '400',
#   'Unemployment Rate': '3.9%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1ee9f'),
#   'City': 'Anaheim',
#   'County': 'Orange',
#   'Population': '336265',
#   'Violent crimes': 1101,
#   'Property Crimes': 8196,
#   'Median Age': '32.40',
#   'Median Home Price': ' 383,000 ',
#   'Labor Force': '170,600',
#   'Employment': '165,300',
#   'Unemployment Number': '5,300',
#   'Unemployment Rate': '3.1%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eea0'),
#   'City': 'Anderson',
#   'County': 'Shasta',
#   'Population': '9932',
#   'Violent crimes': 96,
#   'Property Crimes': 617,
#   'Median Age': '34.10',
#   'Median Home Price': ' 179,000 ',
#   'Labor Force': '4,200',
#   'Employment': '3,900',
#   'Unemployment Number': '300',
#   'Unemployment Rate': '6.1%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eea1'),
#   'City': 'Antioch',
#   'County': 'Contra Costa',
#   'Population': '102372',
#   'Violent crimes': 849,
#   'Property Crimes': 4190,
#   'Median Age': '33.80',
#   'Median Home Price': ' 254,000 ',
#   'Labor Force': '51,500',
#   'Employment': '49,400',
#   'Unemployment Number': '2,100',
#   'Unemployment Rate': '4.1%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eea2'),
#   'City': 'Arcadia',
#   'County': 'Los Angeles',
#   'Population': '56364',
#   'Violent crimes': 60,
#   'Property Crimes': 1159,
#   'Median Age': '43.10',
#   'Median Home Price': ' 538,000 ',
#   'Labor Force': '29,800',
#   'Employment': '28,700',
#   'Unemployment Number': '1,100',
#   'Unemployment Rate': '3.6%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eea3'),
#   'City': 'Arcata',
#   'County': 'Humboldt',
#   'Population': '17231',
#   'Violent crimes': 78,
#   'Property Crimes': 702,
#   'Median Age': '26.10',
#   'Median Home Price': ' 255,000 ',
#   'Labor Force': '9,100',
#   'Employment': '8,500',
#   'Unemployment Number': '600',
#   'Unemployment Rate': '6.1%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eea4'),
#   'City': 'Arroyo Grande',
#   'County': 'San Luis Obispo',
#   'Population': '17252',
#   'Violent crimes': 52,
#   'Property Crimes': 356,
#   'Median Age': '45.40',
#   'Median Home Price': ' 371,000 ',
#   'Labor Force': '9,000',
#   'Employment': '8,700',
#   'Unemployment Number': '200',
#   'Unemployment Rate': '2.7%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eea5'),
#   'City': 'Artesia',
#   'County': 'Los Angeles',
#   'Population': '16522',
#   'Violent crimes': 49,
#   'Property Crimes': 294,
#   'Median Age': '38.20',
#   'Median Home Price': ' 419,000 ',
#   'Labor Force': '8,000',
#   'Employment': '7,800',
#   'Unemployment Number': '200',
#   'Unemployment Rate': '2.8%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eea6'),
#   'City': 'Arvin',
#   'County': 'Kern',
#   'Population': '19304',
#   'Violent crimes': 177,
#   'Property Crimes': 483,
#   'Median Age': '24.00',
#   'Median Home Price': ' 136,000 ',
#   'Labor Force': '9,300',
#   'Employment': '8,600',
#   'Unemployment Number': '700',
#   'Unemployment Rate': '7.2%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eea7'),
#   'City': 'Atascadero',
#   'County': 'San Luis Obispo',
#   'Population': '28310',
#   'Violent crimes': 72,
#   'Property Crimes': 448,
#   'Median Age': '41.00',
#   'Median Home Price': ' 320,000 ',
#   'Labor Force': '15,100',
#   'Employment': '14,700',
#   'Unemployment Number': '500',
#   'Unemployment Rate': '3.0%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eea8'),
#   'City': 'Atwater',
#   'County': 'Merced',
#   'Population': '28168',
#   'Violent crimes': 182,
#   'Property Crimes': 1024,
#   'Median Age': '30.00',
#   'Median Home Price': ' 172,000 ',
#   'Labor Force': '12,200',
#   'Employment': '11,300',
#   'Unemployment Number': '900',
#   'Unemployment Rate': '7.5%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eea9'),
#   'City': 'Auburn',
#   'County': 'Placer',
#   'Population': '13330',
#   'Violent crimes': 44,
#   'Property Crimes': 295,
#   'Median Age': '45.40',
#   'Median Home Price': ' 263,000 ',
#   'Labor Force': '6,900',
#   'Employment': '6,700',
#   'Unemployment Number': '200',
#   'Unemployment Rate': '3.2%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eeaa'),
#   'City': 'Avalon',
#   'County': 'Los Angeles',
#   'Population': '3728',
#   'Violent crimes': 20,
#   'Property Crimes': 89,
#   'Median Age': '37.70',
#   'Median Home Price': ' 629,000 ',
#   'Labor Force': '2,000',
#   'Employment': '2,000',
#   'Unemployment Number': '0',
#   'Unemployment Rate': '1.3%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eeab'),
#   'City': 'Avenal',
#   'County': 'Kings',
#   'Population': '15505',
#   'Violent crimes': 18,
#   'Property Crimes': 154,
#   'Median Age': '34.20',
#   'Median Home Price': ' 110,000 ',
#   'Labor Force': '3,800',
#   'Employment': '3,500',
#   'Unemployment Number': '300',
#   'Unemployment Rate': '9.1%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eeac'),
#   'City': 'Azusa',
#   'County': 'Los Angeles',
#   'Population': '46361',
#   'Violent crimes': 165,
#   'Property Crimes': 1065,
#   'Median Age': '29.30',
#   'Median Home Price': ' 367,000 ',
#   'Labor Force': '25,000',
#   'Employment': '23,900',
#   'Unemployment Number': '1,100',
#   'Unemployment Rate': '4.5%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eead'),
#   'City': 'Bakersfield',
#   'County': 'Kern',
#   'Population': '347483',
#   'Violent crimes': 1678,
#   'Property Crimes': 14595,
#   'Median Age': '30.00',
#   'Median Home Price': ' 145,000 ',
#   'Labor Force': '181,300',
#   'Employment': '170,700',
#   'Unemployment Number': '10,500',
#   'Unemployment Rate': '5.8%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eeae'),
#   'City': 'Baldwin Park',
#   'County': 'Los Angeles',
#   'Population': '75390',
#   'Violent crimes': 219,
#   'Property Crimes': 1342,
#   'Median Age': '30.50',
#   'Median Home Price': ' 377,000 ',
#   'Labor Force': '34,700',
#   'Employment': '33,000',
#   'Unemployment Number': '1,700',
#   'Unemployment Rate': '4.9%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eeaf'),
#   'City': 'Banning',
#   'County': 'Riverside',
#   'Population': '29603',
#   'Violent crimes': 128,
#   'Property Crimes': 619,
#   'Median Age': '42.30',
#   'Median Home Price': ' 193,000 ',
#   'Labor Force': '11,200',
#   'Employment': '10,600',
#   'Unemployment Number': '600',
#   'Unemployment Rate': '5.3%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eeb0'),
#   'City': 'Barstow',
#   'County': 'San Bernardino',
#   'Population': '22639',
#   'Violent crimes': 217,
#   'Property Crimes': 781,
#   'Median Age': '31.10',
#   'Median Home Price': ' 112,000 ',
#   'Labor Force': '8,700',
#   'Employment': '8,200',
#   'Unemployment Number': '500',
#   'Unemployment Rate': '6.1%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eeb1'),
#   'City': 'Beaumont',
#   'County': 'Riverside',
#   'Population': '36877',
#   'Violent crimes': 71,
#   'Property Crimes': 974,
#   'Median Age': '32.50',
#   'Median Home Price': ' 174,000 ',
#   'Labor Force': '21,900',
#   'Employment': '21,200',
#   'Unemployment Number': '700',
#   'Unemployment Rate': '3.3%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eeb2'),
#   'City': 'Bell',
#   'County': 'Los Angeles',
#   'Population': '35477',
#   'Violent crimes': 217,
#   'Property Crimes': 718,
#   'Median Age': '28.90',
#   'Median Home Price': ' 381,000 ',
#   'Labor Force': '15,100',
#   'Employment': '14,400',
#   'Unemployment Number': '800',
#   'Unemployment Rate': '5.2%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eeb3'),
#   'City': 'Bell Gardens',
#   'County': 'Los Angeles',
#   'Population': '42072',
#   'Violent crimes': 108,
#   'Property Crimes': 710,
#   'Median Age': '27.30',
#   'Median Home Price': ' 399,000 ',
#   'Labor Force': '18,100',
#   'Employment': '17,300',
#   'Unemployment Number': '800',
#   'Unemployment Rate': '4.5%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eeb4'),
#   'City': 'Bellflower',
#   'County': 'Los Angeles',
#   'Population': '76616',
#   'Violent crimes': 293,
#   'Property Crimes': 1623,
#   'Median Age': '31.90',
#   'Median Home Price': ' 382,000 ',
#   'Labor Force': '36,600',
#   'Employment': '34,600',
#   'Unemployment Number': '2,000',
#   'Unemployment Rate': '5.3%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eeb5'),
#   'City': 'Belmont',
#   'County': 'San Mateo',
#   'Population': '25835',
#   'Violent crimes': 36,
#   'Property Crimes': 372,
#   'Median Age': '40.90',
#   'Median Home Price': ' 969,000 ',
#   'Labor Force': '17,000',
#   'Employment': '16,600',
#   'Unemployment Number': '400',
#   'Unemployment Rate': '2.2%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eeb6'),
#   'City': 'Benicia',
#   'County': 'Solano',
#   'Population': '26997',
#   'Violent crimes': 26,
#   'Property Crimes': 484,
#   'Median Age': '42.90',
#   'Median Home Price': ' 343,000 ',
#   'Labor Force': '14,800',
#   'Employment': '14,400',
#   'Unemployment Number': '400',
#   'Unemployment Rate': '3.0%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eeb7'),
#   'City': 'Berkeley',
#   'County': 'Alameda',
#   'Population': '112580',
#   'Violent crimes': 431,
#   'Property Crimes': 5102,
#   'Median Age': '31.00',
#   'Median Home Price': ' 817,000 ',
#   'Labor Force': '64,000',
#   'Employment': '62,100',
#   'Unemployment Number': '1,900',
#   'Unemployment Rate': '3.0%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eeb8'),
#   'City': 'Beverly Hills',
#   'County': 'Los Angeles',
#   'Population': '34109',
#   'Violent crimes': 111,
#   'Property Crimes': 1071,
#   'Median Age': '43.60',
#   'Median Home Price': ' 1,287,000 ',
#   'Labor Force': '18,400',
#   'Employment': '17,600',
#   'Unemployment Number': '700',
#   'Unemployment Rate': '4.1%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eeb9'),
#   'City': 'Big Bear Lake',
#   'County': 'San Bernardino',
#   'Population': '5019',
#   'Violent crimes': 44,
#   'Property Crimes': 262,
#   'Median Age': '46.10',
#   'Median Home Price': ' 272,000 ',
#   'Labor Force': '2,400',
#   'Employment': '2,300',
#   'Unemployment Number': '0',
#   'Unemployment Rate': '1.9%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eeba'),
#   'City': 'Biggs',
#   'County': 'Butte',
#   'Population': '1707',
#   'Violent crimes': 17,
#   'Property Crimes': 22,
#   'Median Age': '35.10',
#   'Median Home Price': ' 186,000 ',
#   'Labor Force': '800',
#   'Employment': '800',
#   'Unemployment Number': '100',
#   'Unemployment Rate': '6.0%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eebb'),
#   'City': 'Bishop',
#   'County': 'Inyo',
#   'Population': '3879',
#   'Violent crimes': 27,
#   'Property Crimes': 128,
#   'Median Age': '38.90',
#   'Median Home Price': ' 253,000 ',
#   'Labor Force': '1,820',
#   'Employment': '1,790',
#   'Unemployment Number': '30',
#   'Unemployment Rate': '1.8%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eebc'),
#   'City': 'Blythe',
#   'County': 'Riverside',
#   'Population': '20817',
#   'Violent crimes': 88,
#   'Property Crimes': 748,
#   'Median Age': '38.00',
#   'Median Home Price': ' 110,000 ',
#   'Labor Force': '6,000',
#   'Employment': '5,800',
#   'Unemployment Number': '300',
#   'Unemployment Rate': '4.7%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eebd'),
#   'City': 'Brea',
#   'County': 'Orange',
#   'Population': '39282',
#   'Violent crimes': 53,
#   'Property Crimes': 1124,
#   'Median Age': '38.70',
#   'Median Home Price': ' 374,000 ',
#   'Labor Force': '22,600',
#   'Employment': '21,900',
#   'Unemployment Number': '700',
#   'Unemployment Rate': '2.9%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eebe'),
#   'City': 'Brentwood',
#   'County': 'Contra Costa',
#   'Population': '51481',
#   'Violent crimes': 102,
#   'Property Crimes': 1250,
#   'Median Age': '35.60',
#   'Median Home Price': ' 266,000 ',
#   'Labor Force': '29,200',
#   'Employment': '28,200',
#   'Unemployment Number': '1,000',
#   'Unemployment Rate': '3.3%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eebf'),
#   'City': 'Brisbane',
#   'County': 'San Mateo',
#   'Population': '4282',
#   'Violent crimes': 11,
#   'Property Crimes': 133,
#   'Median Age': '41.70',
#   'Median Home Price': ' 708,000 ',
#   'Labor Force': '3,000',
#   'Employment': '2,900',
#   'Unemployment Number': '100',
#   'Unemployment Rate': '1.7%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eec0'),
#   'City': 'Buellton',
#   'County': 'Santa Barbara',
#   'Population': '4828',
#   'Violent crimes': 6,
#   'Property Crimes': 71,
#   'Median Age': '39.10',
#   'Median Home Price': ' 358,000 ',
#   'Labor Force': '2,800',
#   'Employment': '2,800',
#   'Unemployment Number': '0',
#   'Unemployment Rate': '1.2%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eec1'),
#   'City': 'Buena Park',
#   'County': 'Orange',
#   'Population': '80530',
#   'Violent crimes': 217,
#   'Property Crimes': 2030,
#   'Median Age': '35.10',
#   'Median Home Price': ' 402,000 ',
#   'Labor Force': '40,400',
#   'Employment': '39,000',
#   'Unemployment Number': '1,400',
#   'Unemployment Rate': '3.4%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eec2'),
#   'City': 'Burbank',
#   'County': 'Los Angeles',
#   'Population': '103340',
#   'Violent crimes': 150,
#   'Property Crimes': 2426,
#   'Median Age': '38.90',
#   'Median Home Price': ' 563,000 ',
#   'Labor Force': '59,400',
#   'Employment': '56,300',
#   'Unemployment Number': '3,100',
#   'Unemployment Rate': '5.2%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eec3'),
#   'City': 'Burbank',
#   'County': 'Los Angeles',
#   'Population': '103340',
#   'Violent crimes': 150,
#   'Property Crimes': 2426,
#   'Median Age': '38.90',
#   'Median Home Price': ' 834,000 ',
#   'Labor Force': '59,400',
#   'Employment': '56,300',
#   'Unemployment Number': '3,100',
#   'Unemployment Rate': '5.2%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eec4'),
#   'City': 'Burlingame',
#   'County': 'San Mateo',
#   'Population': '28806',
#   'Violent crimes': 47,
#   'Property Crimes': 750,
#   'Median Age': '40.50',
#   'Median Home Price': ' 1,142,000 ',
#   'Labor Force': '18,700',
#   'Employment': '18,400',
#   'Unemployment Number': '400',
#   'Unemployment Rate': '2.0%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eec5'),
#   'City': 'Calabasas',
#   'County': 'Los Angeles',
#   'Population': '23058',
#   'Violent crimes': 19,
#   'Property Crimes': 252,
#   'Median Age': '41.60',
#   'Median Home Price': ' 457,000 ',
#   'Labor Force': '12,300',
#   'Employment': '11,900',
#   'Unemployment Number': '400',
#   'Unemployment Rate': '3.1%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eec6'),
#   'City': 'Calimesa',
#   'County': 'Riverside',
#   'Population': '7879',
#   'Violent crimes': 17,
#   'Property Crimes': 259,
#   'Median Age': '48.80',
#   'Median Home Price': ' 214,000 ',
#   'Labor Force': '3,400',
#   'Employment': '3,200',
#   'Unemployment Number': '200',
#   'Unemployment Rate': '4.8%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eec7'),
#   'City': 'Calistoga',
#   'County': 'Napa',
#   'Population': '5155',
#   'Violent crimes': 3,
#   'Property Crimes': 73,
#   'Median Age': '40.00',
#   'Median Home Price': ' 594,000 ',
#   'Labor Force': '2,700',
#   'Employment': '2,700',
#   'Unemployment Number': '100',
#   'Unemployment Rate': '2.3%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eec8'),
#   'City': 'Camarillo',
#   'County': 'Ventura',
#   'Population': '65201',
#   'Violent crimes': 72,
#   'Property Crimes': 965,
#   'Median Age': '40.80',
#   'Median Home Price': ' 355,000 ',
#   'Labor Force': '33,000',
#   'Employment': '32,000',
#   'Unemployment Number': '1,000',
#   'Unemployment Rate': '3.2%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eec9'),
#   'City': 'Campbell',
#   'County': 'Santa Clara',
#   'Population': '39349',
#   'Violent crimes': 81,
#   'Property Crimes': 1388,
#   'Median Age': '38.30',
#   'Median Home Price': ' 773,000 ',
#   'Labor Force': '26,400',
#   'Employment': '25,800',
#   'Unemployment Number': '600',
#   'Unemployment Rate': '2.4%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eeca'),
#   'City': 'Canyon Lake',
#   'County': 'Riverside',
#   'Population': '10561',
#   'Violent crimes': 13,
#   'Property Crimes': 128,
#   'Median Age': '44.00',
#   'Median Home Price': ' 222,000 ',
#   'Labor Force': '5,600',
#   'Employment': '5,400',
#   'Unemployment Number': '200',
#   'Unemployment Rate': '3.2%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eecb'),
#   'City': 'Capitola',
#   'County': 'Santa Cruz',
#   'Population': '9918',
#   'Violent crimes': 30,
#   'Property Crimes': 627,
#   'Median Age': '41.90',
#   'Median Home Price': ' 633,000 ',
#   'Labor Force': '5,700',
#   'Employment': '5,600',
#   'Unemployment Number': '100',
#   'Unemployment Rate': '1.8%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eecc'),
#   'City': 'Carlsbad',
#   'County': 'San Diego',
#   'Population': '105328',
#   'Violent crimes': 204,
#   'Property Crimes': 1731,
#   'Median Age': '40.40',
#   'Median Home Price': ' 405,000 ',
#   'Labor Force': '55,500',
#   'Employment': '53,800',
#   'Unemployment Number': '1,700',
#   'Unemployment Rate': '3.1%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eecd'),
#   'City': 'Carpinteria',
#   'County': 'Santa Barbara',
#   'Population': '13040',
#   'Violent crimes': 19,
#   'Property Crimes': 197,
#   'Median Age': '39.50',
#   'Median Home Price': ' 599,000 ',
#   'Labor Force': '7,500',
#   'Employment': '7,200',
#   'Unemployment Number': '300',
#   'Unemployment Rate': '3.5%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eece'),
#   'City': 'Carson',
#   'County': 'Los Angeles',
#   'Population': '91714',
#   'Violent crimes': 339,
#   'Property Crimes': 2116,
#   'Median Age': '37.60',
#   'Median Home Price': ' 357,000 ',
#   'Labor Force': '46,300',
#   'Employment': '43,900',
#   'Unemployment Number': '2,400',
#   'Unemployment Rate': '5.2%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eecf'),
#   'City': 'Ceres',
#   'County': 'Stanislaus',
#   'Population': '45417',
#   'Violent crimes': 145,
#   'Property Crimes': 1584,
#   'Median Age': '29.40',
#   'Median Home Price': ' 194,000 ',
#   'Labor Force': '21,800',
#   'Employment': '20,300',
#   'Unemployment Number': '1,400',
#   'Unemployment Rate': '6.6%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eed0'),
#   'City': 'Cerritos',
#   'County': 'Los Angeles',
#   'Population': '49041',
#   'Violent crimes': 86,
#   'Property Crimes': 1525,
#   'Median Age': '44.00',
#   'Median Home Price': ' 409,000 ',
#   'Labor Force': '25,500',
#   'Employment': '24,500',
#   'Unemployment Number': '1,000',
#   'Unemployment Rate': '3.9%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eed1'),
#   'City': 'Chico',
#   'County': 'Butte',
#   'Population': '86187',
#   'Violent crimes': 340,
#   'Property Crimes': 3213,
#   'Median Age': '28.60',
#   'Median Home Price': ' 247,000 ',
#   'Labor Force': '48,400',
#   'Employment': '46,300',
#   'Unemployment Number': '2,100',
#   'Unemployment Rate': '4.4%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eed2'),
#   'City': 'Chino',
#   'County': 'San Bernardino',
#   'Population': '77983',
#   'Violent crimes': 186,
#   'Property Crimes': 1816,
#   'Median Age': '33.20',
#   'Median Home Price': ' 292,000 ',
#   'Labor Force': '42,800',
#   'Employment': '41,300',
#   'Unemployment Number': '1,500',
#   'Unemployment Rate': '3.5%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eed3'),
#   'City': 'Chino Hills',
#   'County': 'San Bernardino',
#   'Population': '74799',
#   'Violent crimes': 61,
#   'Property Crimes': 1030,
#   'Median Age': '36.60',
#   'Median Home Price': ' 346,000 ',
#   'Labor Force': '44,000',
#   'Employment': '42,800',
#   'Unemployment Number': '1,200',
#   'Unemployment Rate': '2.7%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eed4'),
#   'City': 'Chowchilla',
#   'County': 'Madera',
#   'Population': '18720',
#   'Violent crimes': 89,
#   'Property Crimes': 332,
#   'Median Age': '34.70',
#   'Median Home Price': ' 146,000 ',
#   'Labor Force': '4,400',
#   'Employment': '4,200',
#   'Unemployment Number': '200',
#   'Unemployment Rate': '5.0%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eed5'),
#   'City': 'Chula Vista',
#   'County': 'San Diego',
#   'Population': '243916',
#   'Violent crimes': 612,
#   'Property Crimes': 4524,
#   'Median Age': '33.70',
#   'Median Home Price': ' 302,000 ',
#   'Labor Force': '123,700',
#   'Employment': '119,300',
#   'Unemployment Number': '4,500',
#   'Unemployment Rate': '3.6%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eed6'),
#   'City': 'Citrus Heights',
#   'County': 'Sacramento',
#   'Population': '83301',
#   'Violent crimes': 389,
#   'Property Crimes': 2691,
#   'Median Age': '36.20',
#   'Median Home Price': ' 234,000 ',
#   'Labor Force': '44,000',
#   'Employment': '42,400',
#   'Unemployment Number': '1,600',
#   'Unemployment Rate': '3.7%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eed7'),
#   'City': 'Claremont',
#   'County': 'Los Angeles',
#   'Population': '34926',
#   'Violent crimes': 39,
#   'Property Crimes': 853,
#   'Median Age': '38.60',
#   'Median Home Price': ' 364,000 ',
#   'Labor Force': '17,000',
#   'Employment': '16,200',
#   'Unemployment Number': '800',
#   'Unemployment Rate': '4.5%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eed8'),
#   'City': 'Clayton',
#   'County': 'Contra Costa',
#   'Population': '10897',
#   'Violent crimes': 4,
#   'Property Crimes': 111,
#   'Median Age': '45.00',
#   'Median Home Price': ' 378,000 ',
#   'Labor Force': '6,100',
#   'Employment': '6,000',
#   'Unemployment Number': '100',
#   'Unemployment Rate': '1.8%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eed9'),
#   'City': 'Cloverdale',
#   'County': 'Sonoma',
#   'Population': '8618',
#   'Violent crimes': 15,
#   'Property Crimes': 171,
#   'Median Age': '39.70',
#   'Median Home Price': ' 347,000 ',
#   'Labor Force': '4,500',
#   'Employment': '4,400',
#   'Unemployment Number': '100',
#   'Unemployment Rate': '1.8%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eeda'),
#   'City': 'Clovis',
#   'County': 'Fresno',
#   'Population': '95631',
#   'Violent crimes': 216,
#   'Property Crimes': 3064,
#   'Median Age': '34.10',
#   'Median Home Price': ' 183,000 ',
#   'Labor Force': '55,200',
#   'Employment': '52,700',
#   'Unemployment Number': '2,500',
#   'Unemployment Rate': '4.6%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eedb'),
#   'City': 'Coachella',
#   'County': 'Riverside',
#   'Population': '40704',
#   'Violent crimes': 166,
#   'Property Crimes': 1152,
#   'Median Age': '24.50',
#   'Median Home Price': ' 170,000 ',
#   'Labor Force': '20,500',
#   'Employment': '17,900',
#   'Unemployment Number': '2,700',
#   'Unemployment Rate': '13.0%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eedc'),
#   'City': 'Coalinga',
#   'County': 'Fresno',
#   'Population': '13380',
#   'Violent crimes': 121,
#   'Property Crimes': 315,
#   'Median Age': '31.90',
#   'Median Home Price': ' 121,000 ',
#   'Labor Force': '6,400',
#   'Employment': '6,000',
#   'Unemployment Number': '500',
#   'Unemployment Rate': '7.1%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eedd'),
#   'City': 'Colton',
#   'County': 'San Bernardino',
#   'Population': '52154',
#   'Violent crimes': 137,
#   'Property Crimes': 1575,
#   'Median Age': '28.40',
#   'Median Home Price': ' 235,000 ',
#   'Labor Force': '24,800',
#   'Employment': '23,700',
#   'Unemployment Number': '1,100',
#   'Unemployment Rate': '4.3%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eede'),
#   'City': 'Colusa',
#   'County': 'Colusa',
#   'Population': '5971',
#   'Violent crimes': 9,
#   'Property Crimes': 105,
#   'Median Age': '33.50',
#   'Median Home Price': ' 165,000 ',
#   'Labor Force': '3,100',
#   'Employment': '2,860',
#   'Unemployment Number': '240',
#   'Unemployment Rate': '7.9%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eedf'),
#   'City': 'Commerce',
#   'County': 'Los Angeles',
#   'Population': '12823',
#   'Violent crimes': 77,
#   'Property Crimes': 965,
#   'Median Age': '31.20',
#   'Median Home Price': ' 406,000 ',
#   'Labor Force': '6,000',
#   'Employment': '5,600',
#   'Unemployment Number': '400',
#   'Unemployment Rate': '6.7%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eee0'),
#   'City': 'Compton',
#   'County': 'Los Angeles',
#   'Population': '96455',
#   'Violent crimes': 1129,
#   'Property Crimes': 2619,
#   'Median Age': '28.00',
#   'Median Home Price': ' 363,000 ',
#   'Labor Force': '39,500',
#   'Employment': '36,900',
#   'Unemployment Number': '2,600',
#   'Unemployment Rate': '6.6%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eee1'),
#   'City': 'Concord',
#   'County': 'Contra Costa',
#   'Population': '122067',
#   'Violent crimes': 465,
#   'Property Crimes': 5196,
#   'Median Age': '37.00',
#   'Median Home Price': ' 388,000 ',
#   'Labor Force': '66,900',
#   'Employment': '64,900',
#   'Unemployment Number': '2,100',
#   'Unemployment Rate': '3.1%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eee2'),
#   'City': 'Corcoran',
#   'County': 'Kings',
#   'Population': '24813',
#   'Violent crimes': 86,
#   'Property Crimes': 292,
#   'Median Age': '35.00',
#   'Median Home Price': ' 117,000 ',
#   'Labor Force': '4,600',
#   'Employment': '3,900',
#   'Unemployment Number': '600',
#   'Unemployment Rate': '14.1%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eee3'),
#   'City': 'Corona',
#   'County': 'Riverside',
#   'Population': '152374',
#   'Violent crimes': 171,
#   'Property Crimes': 3440,
#   'Median Age': '32.50',
#   'Median Home Price': ' 264,000 ',
#   'Labor Force': '84,000',
#   'Employment': '81,300',
#   'Unemployment Number': '2,600',
#   'Unemployment Rate': '3.1%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eee4'),
#   'City': 'Coronado',
#   'County': 'San Diego',
#   'Population': '24697',
#   'Violent crimes': 17,
#   'Property Crimes': 545,
#   'Median Age': '40.70',
#   'Median Home Price': ' 978,000 ',
#   'Labor Force': '8,800',
#   'Employment': '8,500',
#   'Unemployment Number': '300',
#   'Unemployment Rate': '3.3%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eee5'),
#   'City': 'Costa Mesa',
#   'County': 'Orange',
#   'Population': '109960',
#   'Violent crimes': 318,
#   'Property Crimes': 3462,
#   'Median Age': '33.60',
#   'Median Home Price': ' 492,000 ',
#   'Labor Force': '65,700',
#   'Employment': '63,900',
#   'Unemployment Number': '1,800',
#   'Unemployment Rate': '2.7%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eee6'),
#   'City': 'Cotati',
#   'County': 'Sonoma',
#   'Population': '7265',
#   'Violent crimes': 33,
#   'Property Crimes': 70,
#   'Median Age': '36.20',
#   'Median Home Price': ' 395,000 ',
#   'Labor Force': '4,400',
#   'Employment': '4,300',
#   'Unemployment Number': '100',
#   'Unemployment Rate': '2.5%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eee7'),
#   'City': 'Covina',
#   'County': 'Los Angeles',
#   'Population': '47796',
#   'Violent crimes': 110,
#   'Property Crimes': 1108,
#   'Median Age': '35.70',
#   'Median Home Price': ' 365,000 ',
#   'Labor Force': '24,100',
#   'Employment': '22,900',
#   'Unemployment Number': '1,100',
#   'Unemployment Rate': '4.7%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eee8'),
#   'City': 'Cudahy',
#   'County': 'Los Angeles',
#   'Population': '23805',
#   'Violent crimes': 81,
#   'Property Crimes': 332,
#   'Median Age': '27.00',
#   'Median Home Price': ' 315,000 ',
#   'Labor Force': '10,100',
#   'Employment': '9,700',
#   'Unemployment Number': '500',
#   'Unemployment Rate': '4.6%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eee9'),
#   'City': 'Cupertino',
#   'County': 'Santa Clara',
#   'Population': '58302',
#   'Violent crimes': 40,
#   'Property Crimes': 1026,
#   'Median Age': '39.90',
#   'Median Home Price': ' 1,077,000 ',
#   'Labor Force': '30,300',
#   'Employment': '29,600',
#   'Unemployment Number': '800',
#   'Unemployment Rate': '2.5%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eeea'),
#   'City': 'Cypress',
#   'County': 'Orange',
#   'Population': '47802',
#   'Violent crimes': 51,
#   'Property Crimes': 752,
#   'Median Age': '39.90',
#   'Median Home Price': ' 397,000 ',
#   'Labor Force': '25,000',
#   'Employment': '24,200',
#   'Unemployment Number': '800',
#   'Unemployment Rate': '3.3%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eeeb'),
#   'City': 'Dana Point',
#   'County': 'Orange',
#   'Population': '33351',
#   'Violent crimes': 71,
#   'Property Crimes': 463,
#   'Median Age': '44.80',
#   'Median Home Price': ' 553,000 ',
#   'Labor Force': '18,700',
#   'Employment': '18,300',
#   'Unemployment Number': '500',
#   'Unemployment Rate': '2.6%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eeec'),
#   'City': 'Davis',
#   'County': 'Yolo',
#   'Population': '65622',
#   'Violent crimes': 84,
#   'Property Crimes': 1455,
#   'Median Age': '25.20',
#   'Median Home Price': ' 377,000 ',
#   'Labor Force': '36,200',
#   'Employment': '35,100',
#   'Unemployment Number': '1,100',
#   'Unemployment Rate': '3.0%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eeed'),
#   'City': 'Del Mar',
#   'County': 'San Diego',
#   'Population': '4161',
#   'Violent crimes': 18,
#   'Property Crimes': 137,
#   'Median Age': '48.60',
#   'Median Home Price': ' 1,258,000 ',
#   'Labor Force': '2,500',
#   'Employment': '2,400',
#   'Unemployment Number': '0',
#   'Unemployment Rate': '1.8%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eeee'),
#   'City': 'Del Rey Oaks',
#   'County': 'Monterey',
#   'Population': '1624',
#   'Violent crimes': 1,
#   'Property Crimes': 52,
#   'Median Age': '46.20',
#   'Median Home Price': ' 470,000 ',
#   'Labor Force': '1,000',
#   'Employment': '1,000',
#   'Unemployment Number': '0',
#   'Unemployment Rate': '4.3%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eeef'),
#   'City': 'Delano',
#   'County': 'Kern',
#   'Population': '53041',
#   'Violent crimes': 215,
#   'Property Crimes': 1486,
#   'Median Age': '28.50',
#   'Median Home Price': ' 156,000 ',
#   'Labor Force': '21,300',
#   'Employment': '17,400',
#   'Unemployment Number': '3,900',
#   'Unemployment Rate': '18.3%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eef0'),
#   'City': 'Desert Hot Springs',
#   'County': 'Riverside',
#   'Population': '25938',
#   'Violent crimes': 168,
#   'Property Crimes': 1160,
#   'Median Age': '31.00',
#   'Median Home Price': ' 149,000 ',
#   'Labor Force': '11,700',
#   'Employment': '10,900',
#   'Unemployment Number': '800',
#   'Unemployment Rate': '6.9%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eef1'),
#   'City': 'Diamond Bar',
#   'County': 'Los Angeles',
#   'Population': '55544',
#   'Violent crimes': 49,
#   'Property Crimes': 722,
#   'Median Age': '41.00',
#   'Median Home Price': ' 374,000 ',
#   'Labor Force': '30,400',
#   'Employment': '29,200',
#   'Unemployment Number': '1,200',
#   'Unemployment Rate': '3.9%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eef2'),
#   'City': 'Dinuba',
#   'County': 'Tulare',
#   'Population': '21453',
#   'Violent crimes': 187,
#   'Property Crimes': 933,
#   'Median Age': '27.20',
#   'Median Home Price': ' 146,000 ',
#   'Labor Force': '11,300',
#   'Employment': '9,900',
#   'Unemployment Number': '1,300',
#   'Unemployment Rate': '11.9%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eef3'),
#   'City': 'Dixon',
#   'County': 'Solano',
#   'Population': '18351',
#   'Violent crimes': 53,
#   'Property Crimes': 428,
#   'Median Age': '33.30',
#   'Median Home Price': ' 255,000 ',
#   'Labor Force': '9,700',
#   'Employment': '9,300',
#   'Unemployment Number': '400',
#   'Unemployment Rate': '4.3%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eef4'),
#   'City': 'Dos Palos',
#   'County': 'Merced',
#   'Population': '4950',
#   'Violent crimes': 51,
#   'Property Crimes': 155,
#   'Median Age': '31.30',
#   'Median Home Price': ' 167,000 ',
#   'Labor Force': '2,100',
#   'Employment': '1,900',
#   'Unemployment Number': '200',
#   'Unemployment Rate': '7.3%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eef5'),
#   'City': 'Downey',
#   'County': 'Los Angeles',
#   'Population': '111772',
#   'Violent crimes': 281,
#   'Property Crimes': 2897,
#   'Median Age': '33.30',
#   'Median Home Price': ' 387,000 ',
#   'Labor Force': '57,500',
#   'Employment': '54,900',
#   'Unemployment Number': '2,600',
#   'Unemployment Rate': '4.5%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eef6'),
#   'City': 'Duarte',
#   'County': 'Los Angeles',
#   'Population': '21321',
#   'Violent crimes': 54,
#   'Property Crimes': 352,
#   'Median Age': '39.90',
#   'Median Home Price': ' 405,000 ',
#   'Labor Force': '11,200',
#   'Employment': '10,600',
#   'Unemployment Number': '600',
#   'Unemployment Rate': '5.3%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eef7'),
#   'City': 'Dublin',
#   'County': 'Alameda',
#   'Population': '46036',
#   'Violent crimes': 70,
#   'Property Crimes': 798,
#   'Median Age': '35.30',
#   'Median Home Price': ' 487,000 ',
#   'Labor Force': '31,700',
#   'Employment': '30,800',
#   'Unemployment Number': '900',
#   'Unemployment Rate': '2.7%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eef8'),
#   'City': 'Dunsmuir',
#   'County': 'Siskiyou',
#   'Population': '1650',
#   'Violent crimes': 5,
#   'Property Crimes': 17,
#   'Median Age': '47.00',
#   'Median Home Price': ' 144,000 ',
#   'Labor Force': '670',
#   'Employment': '630',
#   'Unemployment Number': '30',
#   'Unemployment Rate': '4.7%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eef9'),
#   'City': 'East Palo Alto',
#   'County': 'San Mateo',
#   'Population': '28155',
#   'Violent crimes': 124,
#   'Property Crimes': 574,
#   'Median Age': '28.10',
#   'Median Home Price': ' 804,000 ',
#   'Labor Force': '15,300',
#   'Employment': '14,900',
#   'Unemployment Number': '400',
#   'Unemployment Rate': '2.5%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eefa'),
#   'City': 'Eastvale',
#   'County': 'Riverside',
#   'Population': '53,670[10]',
#   'Violent crimes': 59,
#   'Property Crimes': 929,
#   'Median Age': '30.90',
#   'Median Home Price': ' 197,000 ',
#   'Labor Force': '31,900',
#   'Employment': '30,900',
#   'Unemployment Number': '1,000',
#   'Unemployment Rate': '3.0%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eefb'),
#   'City': 'El Cajon',
#   'County': 'San Diego',
#   'Population': '99478',
#   'Violent crimes': 327,
#   'Property Crimes': 2252,
#   'Median Age': '33.70',
#   'Median Home Price': ' 317,000 ',
#   'Labor Force': '45,700',
#   'Employment': '43,900',
#   'Unemployment Number': '1,800',
#   'Unemployment Rate': '3.9%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eefc'),
#   'City': 'El Cerrito',
#   'County': 'Contra Costa',
#   'Population': '23549',
#   'Violent crimes': 77,
#   'Property Crimes': 926,
#   'Median Age': '43.50',
#   'Median Home Price': ' 610,000 ',
#   'Labor Force': '14,000',
#   'Employment': '13,700',
#   'Unemployment Number': '400',
#   'Unemployment Rate': '2.6%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eefd'),
#   'City': 'El Cerrito',
#   'County': 'Contra Costa',
#   'Population': '23549',
#   'Violent crimes': 77,
#   'Property Crimes': 926,
#   'Median Age': '43.50',
#   'Median Home Price': ' 610,000 ',
#   'Labor Force': '2,400',
#   'Employment': '2,300',
#   'Unemployment Number': '100',
#   'Unemployment Rate': '3.1%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eefe'),
#   'City': 'El Monte',
#   'County': 'Los Angeles',
#   'Population': '113475',
#   'Violent crimes': 333,
#   'Property Crimes': 2213,
#   'Median Age': '31.60',
#   'Median Home Price': ' 379,000 ',
#   'Labor Force': '51,600',
#   'Employment': '49,300',
#   'Unemployment Number': '2,300',
#   'Unemployment Rate': '4.4%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eeff'),
#   'City': 'El Segundo',
#   'County': 'Los Angeles',
#   'Population': '16654',
#   'Violent crimes': 48,
#   'Property Crimes': 538,
#   'Median Age': '39.20',
#   'Median Home Price': ' 698,000 ',
#   'Labor Force': '9,700',
#   'Employment': '9,300',
#   'Unemployment Number': '400',
#   'Unemployment Rate': '3.8%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1ef00'),
#   'City': 'Elk Grove',
#   'County': 'Sacramento',
#   'Population': '153015',
#   'Violent crimes': 622,
#   'Property Crimes': 3072,
#   'Median Age': '34.30',
#   'Median Home Price': ' 219,000 ',
#   'Labor Force': '83,400',
#   'Employment': '80,500',
#   'Unemployment Number': '2,900',
#   'Unemployment Rate': '3.4%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1ef01'),
#   'City': 'Emeryville',
#   'County': 'Alameda',
#   'Population': '10080',
#   'Violent crimes': 117,
#   'Property Crimes': 1603,
#   'Median Age': '35.00',
#   'Median Home Price': ' 664,000 ',
#   'Labor Force': '7,700',
#   'Employment': '7,500',
#   'Unemployment Number': '200',
#   'Unemployment Rate': '2.6%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1ef02'),
#   'City': 'Encinitas',
#   'County': 'San Diego',
#   'Population': '59518',
#   'Violent crimes': 104,
#   'Property Crimes': 908,
#   'Median Age': '41.50',
#   'Median Home Price': ' 575,000 ',
#   'Labor Force': '33,600',
#   'Employment': '32,700',
#   'Unemployment Number': '900',
#   'Unemployment Rate': '2.6%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1ef03'),
#   'City': 'Escalon',
#   'County': 'San Joaquin',
#   'Population': '7132',
#   'Violent crimes': 10,
#   'Property Crimes': 171,
#   'Median Age': '36.00',
#   'Median Home Price': ' 236,000 ',
#   'Labor Force': '3,700',
#   'Employment': '3,600',
#   'Unemployment Number': '0',
#   'Unemployment Rate': '1.3%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1ef04'),
#   'City': 'Escondido',
#   'County': 'San Diego',
#   'Population': '143911',
#   'Violent crimes': 512,
#   'Property Crimes': 3026,
#   'Median Age': '32.50',
#   'Median Home Price': ' 308,000 ',
#   'Labor Force': '69,800',
#   'Employment': '67,600',
#   'Unemployment Number': '2,200',
#   'Unemployment Rate': '3.2%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1ef05'),
#   'City': 'Eureka',
#   'County': 'Humboldt',
#   'Population': '27191',
#   'Violent crimes': 145,
#   'Property Crimes': 2176,
#   'Median Age': '36.20',
#   'Median Home Price': ' 211,000 ',
#   'Labor Force': '12,800',
#   'Employment': '12,300',
#   'Unemployment Number': '500',
#   'Unemployment Rate': '3.9%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1ef06'),
#   'City': 'Exeter',
#   'County': 'Tulare',
#   'Population': '10334',
#   'Violent crimes': 47,
#   'Property Crimes': 305,
#   'Median Age': '31.20',
#   'Median Home Price': ' 153,000 ',
#   'Labor Force': '4,900',
#   'Employment': '4,500',
#   'Unemployment Number': '400',
#   'Unemployment Rate': '8.4%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1ef07'),
#   'City': 'Fairfield',
#   'County': 'Solano',
#   'Population': '105321',
#   'Violent crimes': 519,
#   'Property Crimes': 3873,
#   'Median Age': '33.70',
#   'Median Home Price': ' 258,000 ',
#   'Labor Force': '53,000',
#   'Employment': '51,000',
#   'Unemployment Number': '2,000',
#   'Unemployment Rate': '3.8%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1ef08'),
#   'City': 'Farmersville',
#   'County': 'Tulare',
#   'Population': '10588',
#   'Violent crimes': 52,
#   'Property Crimes': 165,
#   'Median Age': '26.20',
#   'Median Home Price': ' 147,000 ',
#   'Labor Force': '4,900',
#   'Employment': '4,300',
#   'Unemployment Number': '600',
#   'Unemployment Rate': '12.1%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1ef09'),
#   'City': 'Ferndale',
#   'County': 'Humboldt',
#   'Population': '1371',
#   'Violent crimes': 3,
#   'Property Crimes': 17,
#   'Median Age': '47.20',
#   'Median Home Price': ' 228,000 ',
#   'Labor Force': '700',
#   'Employment': '700',
#   'Unemployment Number': '0',
#   'Unemployment Rate': '1.4%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1ef0a'),
#   'City': 'Fillmore',
#   'County': 'Ventura',
#   'Population': '15002',
#   'Violent crimes': 46,
#   'Property Crimes': 122,
#   'Median Age': '31.90',
#   'Median Home Price': ' 318,000 ',
#   'Labor Force': '7,000',
#   'Employment': '6,800',
#   'Unemployment Number': '300',
#   'Unemployment Rate': '3.8%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1ef0b'),
#   'City': 'Firebaugh',
#   'County': 'Fresno',
#   'Population': '7549',
#   'Violent crimes': 75,
#   'Property Crimes': 299,
#   'Median Age': '26.40',
#   'Median Home Price': ' 152,000 ',
#   'Labor Force': '3,900',
#   'Employment': '3,500',
#   'Unemployment Number': '400',
#   'Unemployment Rate': '11.1%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1ef0c'),
#   'City': 'Folsom',
#   'County': 'Sacramento',
#   'Population': '72203',
#   'Violent crimes': 79,
#   'Property Crimes': 1305,
#   'Median Age': '37.60',
#   'Median Home Price': ' 273,000 ',
#   'Labor Force': '37,500',
#   'Employment': '36,300',
#   'Unemployment Number': '1,100',
#   'Unemployment Rate': '3.0%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1ef0d'),
#   'City': 'Fontana',
#   'County': 'San Bernardino',
#   'Population': '196069',
#   'Violent crimes': 710,
#   'Property Crimes': 3710,
#   'Median Age': '28.70',
#   'Median Home Price': ' 243,000 ',
#   'Labor Force': '98,800',
#   'Employment': '95,100',
#   'Unemployment Number': '3,700',
#   'Unemployment Rate': '3.8%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1ef0e'),
#   'City': 'Fortuna',
#   'County': 'Humboldt',
#   'Population': '11926',
#   'Violent crimes': 33,
#   'Property Crimes': 496,
#   'Median Age': '38.10',
#   'Median Home Price': ' 207,000 ',
#   'Labor Force': '5,000',
#   'Employment': '4,800',
#   'Unemployment Number': '200',
#   'Unemployment Rate': '4.4%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1ef0f'),
#   'City': 'Fountain Valley',
#   'County': 'Orange',
#   'Population': '55313',
#   'Violent crimes': 86,
#   'Property Crimes': 1023,
#   'Median Age': '42.60',
#   'Median Home Price': ' 418,000 ',
#   'Labor Force': '28,400',
#   'Employment': '27,500',
#   'Unemployment Number': '900',
#   'Unemployment Rate': '3.1%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1ef10'),
#   'City': 'Fowler',
#   'County': 'Fresno',
#   'Population': '5570',
#   'Violent crimes': 49,
#   'Property Crimes': 158,
#   'Median Age': '31.60',
#   'Median Home Price': ' 153,000 ',
#   'Labor Force': '3,000',
#   'Employment': '2,800',
#   'Unemployment Number': '200',
#   'Unemployment Rate': '6.1%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1ef11'),
#   'City': 'Fremont',
#   'County': 'Alameda',
#   'Population': '214089',
#   'Violent crimes': 284,
#   'Property Crimes': 3910,
#   'Median Age': '36.80',
#   'Median Home Price': ' 684,000 ',
#   'Labor Force': '120,900',
#   'Employment': '117,500',
#   'Unemployment Number': '3,300',
#   'Unemployment Rate': '2.7%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1ef12'),
#   'City': 'Fresno',
#   'County': 'Fresno',
#   'Population': '494665',
#   'Violent crimes': 2382,
#   'Property Crimes': 21101,
#   'Median Age': '29.30',
#   'Median Home Price': ' 159,000 ',
#   'Labor Force': '239,500',
#   'Employment': '224,800',
#   'Unemployment Number': '14,700',
#   'Unemployment Rate': '6.1%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1ef13'),
#   'City': 'Fullerton',
#   'County': 'Orange',
#   'Population': '135161',
#   'Violent crimes': 339,
#   'Property Crimes': 3206,
#   'Median Age': '34.80',
#   'Median Home Price': ' 395,000 ',
#   'Labor Force': '70,400',
#   'Employment': '68,100',
#   'Unemployment Number': '2,300',
#   'Unemployment Rate': '3.2%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1ef14'),
#   'City': 'Galt',
#   'County': 'Sacramento',
#   'Population': '23647',
#   'Violent crimes': 70,
#   'Property Crimes': 574,
#   'Median Age': '32.40',
#   'Median Home Price': ' 238,000 ',
#   'Labor Force': '11,500',
#   'Employment': '11,000',
#   'Unemployment Number': '500',
#   'Unemployment Rate': '4.3%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1ef15'),
#   'City': 'Garden Grove',
#   'County': 'Orange',
#   'Population': '170883',
#   'Violent crimes': 406,
#   'Property Crimes': 3098,
#   'Median Age': '35.60',
#   'Median Home Price': ' 416,000 ',
#   'Labor Force': '81,900',
#   'Employment': '79,200',
#   'Unemployment Number': '2,700',
#   'Unemployment Rate': '3.3%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1ef16'),
#   'City': 'Gardena',
#   'County': 'Los Angeles',
#   'Population': '58829',
#   'Violent crimes': 276,
#   'Property Crimes': 1389,
#   'Median Age': '37.90',
#   'Median Home Price': ' 408,000 ',
#   'Labor Force': '30,400',
#   'Employment': '28,900',
#   'Unemployment Number': '1,500',
#   'Unemployment Rate': '4.9%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1ef17'),
#   'City': 'Gilroy',
#   'County': 'Santa Clara',
#   'Population': '48821',
#   'Violent crimes': 197,
#   'Property Crimes': 1486,
#   'Median Age': '32.40',
#   'Median Home Price': ' 388,000 ',
#   'Labor Force': '30,100',
#   'Employment': '29,300',
#   'Unemployment Number': '900',
#   'Unemployment Rate': '2.9%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1ef18'),
#   'City': 'Glendale',
#   'County': 'Los Angeles',
#   'Population': '191719',
#   'Violent crimes': 186,
#   'Property Crimes': 3073,
#   'Median Age': '41.00',
#   'Median Home Price': ' 534,000 ',
#   'Labor Force': '103,700',
#   'Employment': '99,300',
#   'Unemployment Number': '4,500',
#   'Unemployment Rate': '4.3%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1ef19'),
#   'City': 'Glendora',
#   'County': 'Los Angeles',
#   'Population': '50073',
#   'Violent crimes': 66,
#   'Property Crimes': 1241,
#   'Median Age': '40.20',
#   'Median Home Price': ' 397,000 ',
#   'Labor Force': '26,200',
#   'Employment': '25,100',
#   'Unemployment Number': '1,100',
#   'Unemployment Rate': '4.2%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1ef1a'),
#   'City': 'Goleta',
#   'County': 'Santa Barbara',
#   'Population': '29888',
#   'Violent crimes': 35,
#   'Property Crimes': 422,
#   'Median Age': '36.50',
#   'Median Home Price': ' 532,000 ',
#   'Labor Force': '17,300',
#   'Employment': '16,900',
#   'Unemployment Number': '400',
#   'Unemployment Rate': '2.5%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1ef1b'),
#   'City': 'Gonzales',
#   'County': 'Monterey',
#   'Population': '8187',
#   'Violent crimes': 37,
#   'Property Crimes': 86,
#   'Median Age': '27.00',
#   'Median Home Price': ' 294,000 ',
#   'Labor Force': '4,200',
#   'Employment': '4,100',
#   'Unemployment Number': '0',
#   'Unemployment Rate': '1.1%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1ef1c'),
#   'City': 'Grand Terrace',
#   'County': 'San Bernardino',
#   'Population': '12040',
#   'Violent crimes': 18,
#   'Property Crimes': 248,
#   'Median Age': '36.10',
#   'Median Home Price': ' 227,000 ',
#   'Labor Force': '6,300',
#   'Employment': '6,000',
#   'Unemployment Number': '200',
#   'Unemployment Rate': '3.8%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1ef1d'),
#   'City': 'Grass Valley',
#   'County': 'Nevada',
#   'Population': '12860',
#   'Violent crimes': 109,
#   'Property Crimes': 676,
#   'Median Age': '43.20',
#   'Median Home Price': ' 240,000 ',
#   'Labor Force': '5,790',
#   'Employment': '5,500',
#   'Unemployment Number': '290',
#   'Unemployment Rate': '4.9%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1ef1e'),
#   'City': 'Greenfield',
#   'County': 'Monterey',
#   'Population': '16330',
#   'Violent crimes': 91,
#   'Property Crimes': 319,
#   'Median Age': '25.50',
#   'Median Home Price': ' 249,000 ',
#   'Labor Force': '8,400',
#   'Employment': '8,000',
#   'Unemployment Number': '400',
#   'Unemployment Rate': '4.7%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1ef1f'),
#   'City': 'Gridley',
#   'County': 'Butte',
#   'Population': '6584',
#   'Violent crimes': 88,
#   'Property Crimes': 167,
#   'Median Age': '33.10',
#   'Median Home Price': ' 177,000 ',
#   'Labor Force': '2,800',
#   'Employment': '2,600',
#   'Unemployment Number': '200',
#   'Unemployment Rate': '5.6%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1ef20'),
#   'City': 'Grover Beach',
#   'County': 'San Luis Obispo',
#   'Population': '13156',
#   'Violent crimes': 52,
#   'Property Crimes': 324,
#   'Median Age': '36.90',
#   'Median Home Price': ' 374,000 ',
#   'Labor Force': '6,600',
#   'Employment': '6,400',
#   'Unemployment Number': '200',
#   'Unemployment Rate': '3.0%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1ef21'),
#   'City': 'Guadalupe',
#   'County': 'Santa Barbara',
#   'Population': '7080',
#   'Violent crimes': 10,
#   'Property Crimes': 68,
#   'Median Age': '28.20',
#   'Median Home Price': ' 267,000 ',
#   'Labor Force': '3,200',
#   'Employment': '3,100',
#   'Unemployment Number': '100',
# ...
#   'County': 'El Dorado',
#   'Population': '21403',
#   'Violent crimes': 112,
#   'Property Crimes': 516,
#   'Median Age': '35.60',
#   'Median Home Price': ' 316,000 ',
#   'Labor Force': '12,500',
#   'Employment': '12,000',
#   'Unemployment Number': '500',
#   'Unemployment Rate': '4.3%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eff2'),
#   'City': 'South Pasadena',
#   'County': 'Los Angeles',
#   'Population': '25619',
#   'Violent crimes': 30,
#   'Property Crimes': 475,
#   'Median Age': '40.10',
#   'Median Home Price': ' 692,000 ',
#   'Labor Force': '15,000',
#   'Employment': '14,400',
#   'Unemployment Number': '600',
#   'Unemployment Rate': '4.2%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eff3'),
#   'City': 'South San Francisco',
#   'County': 'San Mateo',
#   'Population': '63632',
#   'Violent crimes': 156,
#   'Property Crimes': 1274,
#   'Median Age': '38.10',
#   'Median Home Price': ' 726,000 ',
#   'Labor Force': '40,000',
#   'Employment': '39,000',
#   'Unemployment Number': '1,000',
#   'Unemployment Rate': '2.4%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eff4'),
#   'City': 'Stanton',
#   'County': 'Orange',
#   'Population': '38186',
#   'Violent crimes': 124,
#   'Property Crimes': 684,
#   'Median Age': '33.00',
#   'Median Home Price': ' 385,000 ',
#   'Labor Force': '18,500',
#   'Employment': '17,900',
#   'Unemployment Number': '600',
#   'Unemployment Rate': '3.1%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eff5'),
#   'City': 'Stockton',
#   'County': 'San Joaquin',
#   'Population': '291707',
#   'Violent crimes': 3988,
#   'Property Crimes': 13148,
#   'Median Age': '30.80',
#   'Median Home Price': ' 189,000 ',
#   'Labor Force': '130,700',
#   'Employment': '121,800',
#   'Unemployment Number': '8,900',
#   'Unemployment Rate': '6.8%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eff6'),
#   'City': 'Sunnyvale',
#   'County': 'Santa Clara',
#   'Population': '140081',
#   'Violent crimes': 167,
#   'Property Crimes': 2356,
#   'Median Age': '35.60',
#   'Median Home Price': ' 1,019,000 ',
#   'Labor Force': '89,000',
#   'Employment': '87,100',
#   'Unemployment Number': '1,900',
#   'Unemployment Rate': '2.1%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eff7'),
#   'City': 'Susanville',
#   'County': 'Lassen',
#   'Population': '17947',
#   'Violent crimes': 107,
#   'Property Crimes': 315,
#   'Median Age': '33.60',
#   'Median Home Price': ' 129,000 ',
#   'Labor Force': '3,100',
#   'Employment': '2,970',
#   'Unemployment Number': '130',
#   'Unemployment Rate': '4.2%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eff8'),
#   'City': 'Sutter Creek',
#   'County': 'Amador',
#   'Population': '2501',
#   'Violent crimes': 3,
#   'Property Crimes': 42,
#   'Median Age': '49.40',
#   'Median Home Price': ' 217,000 ',
#   'Labor Force': '1,020',
#   'Employment': '1,000',
#   'Unemployment Number': '20',
#   'Unemployment Rate': '1.8%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1eff9'),
#   'City': 'Taft',
#   'County': 'Kern',
#   'Population': '9327',
#   'Violent crimes': 46,
#   'Property Crimes': 276,
#   'Median Age': '34.90',
#   'Median Home Price': ' 96,000 ',
#   'Labor Force': '3,000',
#   'Employment': '2,900',
#   'Unemployment Number': '100',
#   'Unemployment Rate': '3.4%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1effa'),
#   'City': 'Tehachapi',
#   'County': 'Kern',
#   'Population': '14414',
#   'Violent crimes': 51,
#   'Property Crimes': 309,
#   'Median Age': '34.40',
#   'Median Home Price': ' 167,000 ',
#   'Labor Force': '3,900',
#   'Employment': '3,700',
#   'Unemployment Number': '200',
#   'Unemployment Rate': '4.5%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1effb'),
#   'City': 'Temecula',
#   'County': 'Riverside',
#   'Population': '100097',
#   'Violent crimes': 100,
#   'Property Crimes': 2535,
#   'Median Age': '33.40',
#   'Median Home Price': ' 222,000 ',
#   'Labor Force': '55,200',
#   'Employment': '53,300',
#   'Unemployment Number': '1,900',
#   'Unemployment Rate': '3.4%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1effc'),
#   'City': 'Thousand Oaks',
#   'County': 'Ventura',
#   'Population': '126683',
#   'Violent crimes': 128,
#   'Property Crimes': 1599,
#   'Median Age': '41.50',
#   'Median Home Price': ' 386,000 ',
#   'Labor Force': '64,100',
#   'Employment': '62,200',
#   'Unemployment Number': '1,900',
#   'Unemployment Rate': '3.0%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1effd'),
#   'City': 'Torrance',
#   'County': 'Los Angeles',
#   'Population': '145538',
#   'Violent crimes': 155,
#   'Property Crimes': 2623,
#   'Median Age': '41.30',
#   'Median Home Price': ' 521,000 ',
#   'Labor Force': '78,600',
#   'Employment': '75,600',
#   'Unemployment Number': '3,000',
#   'Unemployment Rate': '3.8%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1effe'),
#   'City': 'Tracy',
#   'County': 'San Joaquin',
#   'Population': '82922',
#   'Violent crimes': 129,
#   'Property Crimes': 2262,
#   'Median Age': '32.30',
#   'Median Home Price': ' 251,000 ',
#   'Labor Force': '43,700',
#   'Employment': '41,800',
#   'Unemployment Number': '1,900',
#   'Unemployment Rate': '4.4%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1efff'),
#   'City': 'Tulare',
#   'County': 'Tulare',
#   'Population': '59278',
#   'Violent crimes': 457,
#   'Property Crimes': 2054,
#   'Median Age': '29.10',
#   'Median Home Price': ' 141,000 ',
#   'Labor Force': '28,300',
#   'Employment': '26,500',
#   'Unemployment Number': '1,800',
#   'Unemployment Rate': '6.4%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1f000'),
#   'City': 'Turlock',
#   'County': 'Stanislaus',
#   'Population': '68549',
#   'Violent crimes': 372,
#   'Property Crimes': 2510,
#   'Median Age': '32.50',
#   'Median Home Price': ' 212,000 ',
#   'Labor Force': '34,600',
#   'Employment': '32,800',
#   'Unemployment Number': '1,800',
#   'Unemployment Rate': '5.1%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1f001'),
#   'City': 'Tustin',
#   'County': 'Orange',
#   'Population': '75540',
#   'Violent crimes': 132,
#   'Property Crimes': 1356,
#   'Median Age': '33.40',
#   'Median Home Price': ' 419,000 ',
#   'Labor Force': '42,800',
#   'Employment': '41,600',
#   'Unemployment Number': '1,200',
#   'Unemployment Rate': '2.8%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1f002'),
#   'City': 'Twentynine Palms',
#   'County': 'San Bernardino',
#   'Population': '25048',
#   'Violent crimes': 62,
#   'Property Crimes': 301,
#   'Median Age': '23.50',
#   'Median Home Price': ' 115,000 ',
#   'Labor Force': '7,100',
#   'Employment': '6,700',
#   'Unemployment Number': '400',
#   'Unemployment Rate': '5.5%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1f003'),
#   'City': 'Upland',
#   'County': 'San Bernardino',
#   'Population': '73732',
#   'Violent crimes': 170,
#   'Property Crimes': 2165,
#   'Median Age': '36.10',
#   'Median Home Price': ' 301,000 ',
#   'Labor Force': '39,700',
#   'Employment': '38,300',
#   'Unemployment Number': '1,400',
#   'Unemployment Rate': '3.4%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1f004'),
#   'City': 'Vacaville',
#   'County': 'Solano',
#   'Population': '92428',
#   'Violent crimes': 268,
#   'Property Crimes': 2587,
#   'Median Age': '37.20',
#   'Median Home Price': ' 270,000 ',
#   'Labor Force': '45,800',
#   'Employment': '44,200',
#   'Unemployment Number': '1,600',
#   'Unemployment Rate': '3.5%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1f005'),
#   'City': 'Vallejo',
#   'County': 'Solano',
#   'Population': '115942',
#   'Violent crimes': 1034,
#   'Property Crimes': 4877,
#   'Median Age': '37.90',
#   'Median Home Price': ' 283,000 ',
#   'Labor Force': '56,500',
#   'Employment': '54,000',
#   'Unemployment Number': '2,400',
#   'Unemployment Rate': '4.3%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1f006'),
#   'City': 'Victorville',
#   'County': 'San Bernardino',
#   'Population': '115903',
#   'Violent crimes': 642,
#   'Property Crimes': 4374,
#   'Median Age': '29.50',
#   'Median Home Price': ' 142,000 ',
#   'Labor Force': '46,300',
#   'Employment': '43,500',
#   'Unemployment Number': '2,800',
#   'Unemployment Rate': '6.0%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1f007'),
#   'City': 'Villa Park',
#   'County': 'Orange',
#   'Population': '5812',
#   'Violent crimes': 5,
#   'Property Crimes': 84,
#   'Median Age': '49.60',
#   'Median Home Price': ' 392,000 ',
#   'Labor Force': '2,500',
#   'Employment': '2,400',
#   'Unemployment Number': '100',
#   'Unemployment Rate': '4.6%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1f008'),
#   'City': 'Visalia',
#   'County': 'Tulare',
#   'Population': '124442',
#   'Violent crimes': 484,
#   'Property Crimes': 3796,
#   'Median Age': '31.60',
#   'Median Home Price': ' 147,000 ',
#   'Labor Force': '62,600',
#   'Employment': '59,100',
#   'Unemployment Number': '3,500',
#   'Unemployment Rate': '5.6%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1f009'),
#   'City': 'Vista',
#   'County': 'San Diego',
#   'Population': '93834',
#   'Violent crimes': 340,
#   'Property Crimes': 1686,
#   'Median Age': '31.10',
#   'Median Home Price': ' 321,000 ',
#   'Labor Force': '45,500',
#   'Employment': '43,900',
#   'Unemployment Number': '1,600',
#   'Unemployment Rate': '3.5%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1f00a'),
#   'City': 'Walnut',
#   'County': 'Los Angeles',
#   'Population': '29172',
#   'Violent crimes': 29,
#   'Property Crimes': 294,
#   'Median Age': '43.10',
#   'Median Home Price': ' 398,000 ',
#   'Labor Force': '16,000',
#   'Employment': '15,400',
#   'Unemployment Number': '600',
#   'Unemployment Rate': '3.5%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1f00b'),
#   'City': 'Walnut Creek',
#   'County': 'Contra Costa',
#   'Population': '64173',
#   'Violent crimes': 74,
#   'Property Crimes': 2439,
#   'Median Age': '47.90',
#   'Median Home Price': ' 508,000 ',
#   'Labor Force': '34,800',
#   'Employment': '33,900',
#   'Unemployment Number': '900',
#   'Unemployment Rate': '2.7%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1f00c'),
#   'City': 'Waterford',
#   'County': 'Stanislaus',
#   'Population': '8456',
#   'Violent crimes': 18,
#   'Property Crimes': 196,
#   'Median Age': '29.60',
#   'Median Home Price': ' 204,000 ',
#   'Labor Force': '3,600',
#   'Employment': '3,200',
#   'Unemployment Number': '400',
#   'Unemployment Rate': '10.3%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1f00d'),
#   'City': 'Watsonville',
#   'County': 'Santa Cruz',
#   'Population': '51199',
#   'Violent crimes': 265,
#   'Property Crimes': 1489,
#   'Median Age': '29.20',
#   'Median Home Price': ' 404,000 ',
#   'Labor Force': '25,200',
#   'Employment': '23,900',
#   'Unemployment Number': '1,200',
#   'Unemployment Rate': '5.0%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1f00e'),
#   'City': 'Weed',
#   'County': 'Siskiyou',
#   'Population': '2967',
#   'Violent crimes': 20,
#   'Property Crimes': 84,
#   'Median Age': '32.70',
#   'Median Home Price': ' 143,000 ',
#   'Labor Force': '1,140',
#   'Employment': '1,070',
#   'Unemployment Number': '70',
#   'Unemployment Rate': '6.1%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1f00f'),
#   'City': 'West Covina',
#   'County': 'Los Angeles',
#   'Population': '106098',
#   'Violent crimes': 225,
#   'Property Crimes': 2832,
#   'Median Age': '36.00',
#   'Median Home Price': ' 361,000 ',
#   'Labor Force': '53,100',
#   'Employment': '50,600',
#   'Unemployment Number': '2,400',
#   'Unemployment Rate': '4.6%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1f010'),
#   'City': 'West Hollywood',
#   'County': 'Los Angeles',
#   'Population': '34399',
#   'Violent crimes': 267,
#   'Property Crimes': 1325,
#   'Median Age': '40.40',
#   'Median Home Price': ' 732,000 ',
#   'Labor Force': '27,200',
#   'Employment': '25,800',
#   'Unemployment Number': '1,400',
#   'Unemployment Rate': '5.0%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1f011'),
#   'City': 'West Sacramento',
#   'County': 'Yolo',
#   'Population': '48744',
#   'Violent crimes': 262,
#   'Property Crimes': 1295,
#   'Median Age': '33.60',
#   'Median Home Price': ' 234,000 ',
#   'Labor Force': '25,900',
#   'Employment': '24,900',
#   'Unemployment Number': '1,000',
#   'Unemployment Rate': '3.9%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1f012'),
#   'City': 'Westlake Village',
#   'County': 'Los Angeles',
#   'Population': '8270',
#   'Violent crimes': 7,
#   'Property Crimes': 173,
#   'Median Age': '48.70',
#   'Median Home Price': ' 464,000 ',
#   'Labor Force': '4,000',
#   'Employment': '3,900',
#   'Unemployment Number': '100',
#   'Unemployment Rate': '2.5%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1f013'),
#   'City': 'Westminster',
#   'County': 'Orange',
#   'Population': '89701',
#   'Violent crimes': 194,
#   'Property Crimes': 2210,
#   'Median Age': '38.70',
#   'Median Home Price': ' 418,000 ',
#   'Labor Force': '41,900',
#   'Employment': '40,500',
#   'Unemployment Number': '1,400',
#   'Unemployment Rate': '3.3%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1f014'),
#   'City': 'Wheatland',
#   'County': 'Yuba',
#   'Population': '3456',
#   'Violent crimes': 4,
#   'Property Crimes': 50,
#   'Median Age': '33.20',
#   'Median Home Price': ' 211,000 ',
#   'Labor Force': '1,700',
#   'Employment': '1,600',
#   'Unemployment Number': '100',
#   'Unemployment Rate': '7.5%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1f015'),
#   'City': 'Whittier',
#   'County': 'Los Angeles',
#   'Population': '85331',
#   'Violent crimes': 239,
#   'Property Crimes': 2247,
#   'Median Age': '35.40',
#   'Median Home Price': ' 387,000 ',
#   'Labor Force': '44,100',
#   'Employment': '41,900',
#   'Unemployment Number': '2,100',
#   'Unemployment Rate': '4.9%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1f016'),
#   'City': 'Wildomar',
#   'County': 'Riverside',
#   'Population': '32176',
#   'Violent crimes': 39,
#   'Property Crimes': 550,
#   'Median Age': '34.60',
#   'Median Home Price': ' 189,000 ',
#   'Labor Force': '17,500',
#   'Employment': '16,900',
#   'Unemployment Number': '700',
#   'Unemployment Rate': '3.8%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1f017'),
#   'City': 'Williams',
#   'County': 'Colusa',
#   'Population': '5123',
#   'Violent crimes': 6,
#   'Property Crimes': 64,
#   'Median Age': '28.30',
#   'Median Home Price': ' 157,000 ',
#   'Labor Force': '2,920',
#   'Employment': '2,730',
#   'Unemployment Number': '200',
#   'Unemployment Rate': '6.7%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1f018'),
#   'City': 'Willows',
#   'County': 'Glenn',
#   'Population': '6166',
#   'Violent crimes': 22,
#   'Property Crimes': 167,
#   'Median Age': '32.60',
#   'Median Home Price': ' 153,000 ',
#   'Labor Force': '2,630',
#   'Employment': '2,460',
#   'Unemployment Number': '170',
#   'Unemployment Rate': '6.4%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1f019'),
#   'City': 'Winters',
#   'County': 'Yolo',
#   'Population': '6624',
#   'Violent crimes': 21,
#   'Property Crimes': 155,
#   'Median Age': '35.90',
#   'Median Home Price': ' 292,000 ',
#   'Labor Force': '3,900',
#   'Employment': '3,700',
#   'Unemployment Number': '200',
#   'Unemployment Rate': '4.8%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1f01a'),
#   'City': 'Woodlake',
#   'County': 'Tulare',
#   'Population': '7279',
#   'Violent crimes': 30,
#   'Property Crimes': 122,
#   'Median Age': '26.40',
#   'Median Home Price': ' 140,000 ',
#   'Labor Force': '3,500',
#   'Employment': '3,000',
#   'Unemployment Number': '400',
#   'Unemployment Rate': '12.3%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1f01b'),
#   'City': 'Woodland',
#   'County': 'Yolo',
#   'Population': '55468',
#   'Violent crimes': 298,
#   'Property Crimes': 1756,
#   'Median Age': '33.70',
#   'Median Home Price': ' 245,000 ',
#   'Labor Force': '30,500',
#   'Employment': '29,200',
#   'Unemployment Number': '1,300',
#   'Unemployment Rate': '4.4%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1f01c'),
#   'City': 'Yorba Linda',
#   'County': 'Orange',
#   'Population': '64234',
#   'Violent crimes': 45,
#   'Property Crimes': 702,
#   'Median Age': '41.70',
#   'Median Home Price': ' 386,000 ',
#   'Labor Force': '35,000',
#   'Employment': '34,000',
#   'Unemployment Number': '1,000',
#   'Unemployment Rate': '2.7%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1f01d'),
#   'City': 'Yreka',
#   'County': 'Siskiyou',
#   'Population': '7765',
#   'Violent crimes': 62,
#   'Property Crimes': 298,
#   'Median Age': '41.70',
#   'Median Home Price': ' 135,000 ',
#   'Labor Force': '2,810',
#   'Employment': '2,630',
#   'Unemployment Number': '190',
#   'Unemployment Rate': '6.6%'},
#  {'_id': ObjectId('5da655ec57b4a93712a1f01e'),
#   'City': 'Yucaipa',
#   'County': 'San Bernardino',
#   'Population': '51367',
#   'Violent crimes': 71,
#   'Property Crimes': 978,
#   'Median Age': '37.80',
#   'Median Home Price': ' 220,000 ',
#   'Labor Force': '25,300',
#   'Employment': '24,400',
#   'Unemployment Number': '800',
#   'Unemployment Rate': '3.4%'}]

# %%
cal_collection.find_one({'City':'San Diego'})
# Out:
# {'_id': ObjectId('5da655ec57b4a93712a1efc4'),
#  'City': 'San Diego',
#  'County': 'San Diego',
#  'Population': '1301617',
#  'Violent crimes': 5214,
#  'Property Crimes': 26812,
#  'Median Age': '33.60',
#  'Median Home Price': ' 437,000 ',
#  'Labor Force': '722,100',
#  'Employment': '698,600',
#  'Unemployment Number': '23,500',
#  'Unemployment Rate': '3.2%'}

# %%
cal_collection.find_one({'Violent crimes': {'$eq': 20}})
# Out:
# {'_id': ObjectId('5da655ec57b4a93712a1eeaa'),
#  'City': 'Avalon',
#  'County': 'Los Angeles',
#  'Population': '3728',
#  'Violent crimes': 20,
#  'Property Crimes': 89,
#  'Median Age': '37.70',
#  'Median Home Price': ' 629,000 ',
#  'Labor Force': '2,000',
#  'Employment': '2,000',
#  'Unemployment Number': '0',
#  'Unemployment Rate': '1.3%'}

# %%
# PyMongo Operators

#    Name                Description
#    --------        -----------------------------------
#    $eq	         Matches values that are equal to a specified value.
#    $gt	         Matches values that are greater than a specified value.
#    $gte	         Matches values that are greater than or equal to a specified value.
#    $in	         Matches any of the values specified in an array.
#    $lt	         Matches values that are less than a specified value.
#    $lte	         Matches values that are less than or equal to a specified value.
#    $ne	         Matches all values that are not equal to a specified value.
#    $nin	         Matches none of the values specified in an array.
